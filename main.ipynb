# %%
# Jupyter Notebook Steps

# Step 1: Load and preprocess data
from src.data_preprocessing import load_and_preprocess_data
X_train, scaler = load_and_preprocess_data("data/simulated_wearable_data.csv")

# Step 2: Train LSTM model
from src.model_training import build_and_train_model
model = build_and_train_model(X_train)

# Step 3: Detect anomalies
from src.anomaly_detection import detect_anomalies
mse, anomalies = detect_anomalies(X_train, model, threshold=np.percentile(mse, 95))
# Out:
# Data preprocessed with sequences shape: (4950, 50, 5)
# c:\Users\Omkar\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 8s 26ms/step - loss: 0.0876 - val_loss: 0.0154
# Epoch 2/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 3s 20ms/step - loss: 0.0137 - val_loss: 0.0069
# Epoch 3/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - loss: 0.0061 - val_loss: 0.0035
# Epoch 4/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 0.0031 - val_loss: 0.0020
# Epoch 5/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.0019 - val_loss: 0.0013
# Epoch 6/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - loss: 0.0013 - val_loss: 9.1483e-04
# Epoch 7/10
# 124/124 ━━━━━━━━━━━━━━━━━━━━ 3s 24ms/step - loss: 8.5171e-04 - val_loss: 5.0872e-04
# ...
